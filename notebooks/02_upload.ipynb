# %%
import sys
sys.path.append('..')

# %%
from src.storage.functions import GPCUtils
import os

# %%
gpc = GPCUtils(folder_id = "1TjGke5eYzgaCZVaXB-4BPaYPBmXvwYox",
               quota_project = "idyllic-kit-475618-v5")

# %%
base_conf = os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), 'conf'))
CLIENT_PATH = os.path.join(base_conf, 'client_secret.json')
TOKEN_PATH  = os.path.join(base_conf, 'tokens.json')

# %%
if os.path.exists(TOKEN_PATH):
    gpc.auth()

# %%
gpc.list_files()
# Out:
# ✅ 1 archivo(s) encontrados:
#  - prueba.xlsx (1o3LBa1qy-5QRMh7jFvdB4WX_edWqKmqN)
# [{'id': '1o3LBa1qy-5QRMh7jFvdB4WX_edWqKmqN',
#   'name': 'prueba.xlsx',
#   'mimeType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#   'webViewLink': 'https://docs.google.com/spreadsheets/d/1o3LBa1qy-5QRMh7jFvdB4WX_edWqKmqN/edit?usp=drivesdk&ouid=100348196114828262291&rtpof=true&sd=true'}]
